# %%
# !pip install pyit2fls
# Out:
# Collecting pyit2fls
#   Downloading pyit2fls-0.8.6-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\adity\appdata\roaming\python\python312\site-packages (from pyit2fls) (1.26.2)
# Requirement already satisfied: scipy in c:\users\adity\appdata\roaming\python\python312\site-packages (from pyit2fls) (1.13.0)
# Requirement already satisfied: matplotlib in c:\users\adity\appdata\roaming\python\python312\site-packages (from pyit2fls) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adity\appdata\roaming\python\python312\site-packages (from matplotlib->pyit2fls) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\adity\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->pyit2fls) (1.16.0)
# Downloading pyit2fls-0.8.6-py3-none-any.whl (32 kB)
# Installing collected packages: pyit2fls
# Successfully installed pyit2fls-0.8.6
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from numpy import linspace
import matplotlib.pyplot as plt
from pyit2fls import zero_mf, singleton_mf, const_mf, tri_mf, ltri_mf, rtri_mf, trapezoid_mf, gaussian_mf

# %%
domain = linspace(0., 1, 1001)
zero = zero_mf(domain)

# %%
singleton = singleton_mf(domain,[0.5,0.6])
const = const_mf(domain, [0.4])
tri = tri_mf(domain,[0., 0.5, 1., 1.])
ltri = ltri_mf(domain, [0.5,1., 1.])
rtri = rtri_mf(domain, [0.5,0., 1.])
trapezoid = trapezoid_mf(domain, [0., 0.2, 0.8, 1., 1.])
gaussian = gaussian_mf(domain,[0.3,0.1, 1.])

# %%
plt.figure()
plt.plot(domain, zero, label="All zero MF")
plt.plot(domain, const, label="Const MF")
plt.grid(True)
plt.legend()
plt.xlabel("Domain")
plt.ylabel("Membership Function")
plt.show()

# %%
plt.figure()
plt.plot(domain, singleton, label="Singleton MF")
plt.grid(True)
plt.legend()
plt.xlabel("Domain")
plt.ylabel("Membership Function")
plt.show()

# %%
plt.figure()
plt.plot(domain, tri, label="Triangular MF")
plt.plot(domain, ltri, label="Left Triangular MF")
plt.plot(domain, rtri, label="Right Triangular MF")
plt.grid(True)
plt.legend()
plt.xlabel("Domain")
plt.ylabel("Membership Function")
plt.show()

# %%
plt.figure()
plt.plot(domain, trapezoid, label="Trapeziod MF")
plt.plot(domain, const, label="Const MF")
plt.grid(True)
plt.legend()
plt.xlabel("Domain")
plt.ylabel("Membership Function")
plt.show()

# %%
plt.figure()
plt.plot(domain, gaussian, label="Gaussian MF")
plt.grid(True)
plt.legend()
plt.xlabel("Domain")
plt.ylabel("Membership Function")
plt.show()
